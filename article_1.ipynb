# %% [markdown]
# Consider the following SCM with three variables:
# \begin{align}
# Z&:=N_Z \\
# Y&:=3*Z + N_Y \\
# X&:=2*(Z-1)+ N_X \\
# \end{align}
# with $N_X, N_Y and N_Z$ being jointly independent
#
# We generate an i.i.d. sample of size 300 from the joint distribution (X,Y,Z).

# %%
#Defining the systems variables
import numpy as np
import pandas as p
import random
import matplotlib.pyplot as plt
random.seed(10)
Z = np.random.normal(loc = 3, scale=1, size = 300).reshape(-1, 1)
Y = 3*Z + np.random.normal(loc = 1, scale=0.5, size = 300).reshape(-1, 1)
X = 2*(Z-1)+ np.random.normal(loc = 3, scale=1, size = 300).reshape(-1, 1)

# %% [markdown]
# Regressing X on Y will result in a decent prediction model although no actual dependency between X and Y exists

# %%
#regress X on Y
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
result = linreg.fit(X, Y)

#evaluate the regression
r_sq = result.score(X, Y)
print(r_sq)
# Out:
# 0.7648654891966132

# %%
#visualize the association
plt.scatter(X, Y,color='blue')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
#the effect of intervening on X
random.seed(10)
Z = np.random.normal(loc = 3, scale=1, size = 300).reshape(-1, 1)
Y = 3*Z + np.random.normal(loc = 1, scale=0.5, size = 300).reshape(-1, 1)
X = np.random.normal(loc = 3, scale=1, size = 300).reshape(-1, 1)

# %%
linreg2 = LinearRegression()
result2 = linreg2.fit(X, Y)
#evaluate the regression
r_sq_2 = result2.score(X, Y)
print(r_sq_2)
# Out:
# 0.011864709350244529

# %%
#visualize the association
plt.scatter(X, Y,color='blue')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
